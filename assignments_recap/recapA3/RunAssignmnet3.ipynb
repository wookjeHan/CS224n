# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs224n/assignments/recapA3'

assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# %cd drive/MyDrive/cs224n/assignments/recapA3/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/cs224n/assignments/recapA3

# %%
# !python parser_transitions.py part_c
# !python parser_transitions.py part_d
# !python parser_model.py -e -f
# !python run.py -d

# %%
# !python run.py
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Loading data...
# took 1.80 seconds
# Building parser...
# took 1.05 seconds
# Loading pretrained embeddings...
# took 2.27 seconds
# Vectorizing data...
# took 1.71 seconds
# Preprocessing training data...
# took 39.06 seconds
# took 0.01 seconds
#
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 10
# 100% 1848/1848 [01:40<00:00, 18.34it/s]
# Average Train Loss: 0.18805991397017524
# Evaluating on dev set
# 1445850it [00:00, 46690029.17it/s]
# - dev UAS: 83.95
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [01:44<00:00, 17.62it/s]
# Average Train Loss: 0.11694204753659891
# Evaluating on dev set
# 1445850it [00:00, 48229158.89it/s]
# - dev UAS: 86.02
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 1848/1848 [01:44<00:00, 17.74it/s]
# Average Train Loss: 0.10223730420693755
# Evaluating on dev set
# 1445850it [00:00, 48845260.23it/s]
# - dev UAS: 87.27
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# 100% 1848/1848 [01:43<00:00, 17.91it/s]
# Average Train Loss: 0.09301460050530248
# Evaluating on dev set
# 1445850it [00:00, 48652849.60it/s]
# - dev UAS: 87.69
# New best dev UAS! Saving model.
#
# Epoch 5 out of 10
# 100% 1848/1848 [01:43<00:00, 17.81it/s]
# Average Train Loss: 0.0865972163558845
# Evaluating on dev set
# 1445850it [00:00, 47640753.52it/s]
# - dev UAS: 87.99
# New best dev UAS! Saving model.
#
# Epoch 6 out of 10
# 100% 1848/1848 [01:45<00:00, 17.56it/s]
# Average Train Loss: 0.08145537295326333
# Evaluating on dev set
# 1445850it [00:00, 48468146.09it/s]
# - dev UAS: 87.96
#
# Epoch 7 out of 10
# 100% 1848/1848 [01:42<00:00, 18.04it/s]
# Average Train Loss: 0.07725851043042811
# Evaluating on dev set
# 1445850it [00:00, 40786183.22it/s]
# - dev UAS: 88.28
# New best dev UAS! Saving model.
#
# Epoch 8 out of 10
# 100% 1848/1848 [01:42<00:00, 18.03it/s]
# Average Train Loss: 0.07350655002479171
# Evaluating on dev set
# 1445850it [00:00, 47295215.67it/s]
# - dev UAS: 88.54
# New best dev UAS! Saving model.
#
# Epoch 9 out of 10
# 100% 1848/1848 [01:42<00:00, 18.01it/s]
# Average Train Loss: 0.0701126174243304
# Evaluating on dev set
# 1445850it [00:00, 48749452.87it/s]
# - dev UAS: 88.71
# New best dev UAS! Saving model.
#
# Epoch 10 out of 10
# 100% 1848/1848 [01:42<00:00, 18.11it/s]
# Average Train Loss: 0.0671996999415065
# Evaluating on dev set
# 1445850it [00:00, 48849194.79it/s]
# - dev UAS: 88.60
#
# ================================================================================
# TESTING
# ================================================================================
# Restoring the best model weights found on the dev set
# Final evaluation on test set
# 2919736it [00:00, 69879202.64it/s]
# - test UAS: 89.19
# Done!
